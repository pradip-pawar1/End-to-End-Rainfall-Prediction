# %% [markdown]
# # Rainfall prediction Final ML model

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('../data/processed.csv')

# %%
df.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0     10.8     21.2       0.0          1.8      6.60           22.0
# 1      3.7     19.0       0.0          1.4      7.61           24.0
# 2      9.6     15.8       0.0          2.6      7.61           52.0
# 3     10.1     15.5      16.6          0.8      7.61           50.0
# 4     11.2     16.2       1.8          0.6      7.61           30.0
#
#    RainTomorrow  Pressure_mean  Pressure_diff  WindSpeed_mean  ...  \
# 0             0        1026.55           -3.7             8.0  ...
# 1             0        1022.65           -3.1             5.5  ...
# 2             1        1014.70           -6.4            14.5  ...
# 3             1        1007.70            0.6            21.5  ...
# 4             1        1018.80            0.8            14.0  ...
#
#    Humidity_diff  Cloud_mean  Cloud_diff  Temp_range  Temp_diff  Month  \
# 0          -18.0        4.48        0.06       18.35        5.3      4
# 1          -43.0        4.48        0.06       14.05        8.9      7
# 2           16.0        4.48        0.06       15.05        0.7      7
# 3          -16.0        4.48        0.06       12.60        2.8      7
# 4          -19.0        4.48        0.06       14.15        2.3      7
#
#    WindDir9am_angle  WindDir3pm_angle  WindGustDir_angle  ClimateZone
# 0              67.5             315.0               67.5            4
# 1               0.0              22.5                0.0            4
# 2              22.5              45.0               45.0            4
# 3             315.0             315.0               22.5            4
# 4             292.5             292.5              315.0            4
#
# [5 rows x 22 columns]

# %%
# Split data into X & y

X = df.drop('RainTomorrow', axis = 1)
y = df['RainTomorrow']

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X = scaler.fit_transform(X)

# %%
# Traning final model
from xgboost import XGBClassifier

final_model = XGBClassifier(
    subsample=0.8,
    n_estimators=200,
    max_depth=8,
    learning_rate=0.05,
    colsample_bytree=0.8,
    random_state=42
)

final_model.fit(X, y)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.05, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=8,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=200,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
def predict_with_threshold(model, X, threshold=0.45):
    probs = model.predict_proba(X)[:, 1]
    return (probs >= threshold).astype(int)

# %%
# Save model as pkl

import pickle

model_package = {
    "model": final_model,
    "threshold": 0.45
}
# Save as .pkl file

# with open("rain_model.pkl", "wb") as f:
#     pickle.dump(model_package, f)
